# %% [markdown]
# ## Principal component analysis (PCA)
#
# 主成份分析的基本假設，是希望資料可以在特徵空間找到一個投影軸(向量)投影後，可以得到這組資料的最大變異量。
#
# #### 優點：
# 1. 特徵降維來避免因維度災難所造成的過度適合(Overfitting)現象
# 2. 降維之後有利於視覺化
#
#
# #### 注意事項：
# 1. 在轉換為新特徵子空間前，要先做"特徵標準化"，原因是PCA非常敏感於資料縮放，因此，如果原特徵是以不同尺度規範量度的話，那就一定要做"特徵標準化"，讓所有的特徵都有相同的尺規。

# %%
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

iris = datasets.load_iris()

X = iris.data
y = iris.target
target_names = iris.target_names

print('X shape: ', X.shape) # 150 筆資料，每筆資料有 4 維
print('y shape: ', y.shape) # 150 個 y classes
# Out:
# X shape:  (150, 4)
# y shape:  (150,)

# %%
print(X[0:3]) # show first 3 data
print(y[0:3]) # index for target name
print(target_names) # target name
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]]
# [0 0 0]
# ['setosa' 'versicolor' 'virginica']

# %%
pca = PCA(n_components=2)
X_r = pca.fit_transform(X)

# %%
plt.figure(figsize=(30, 10))
colors = ['r', 'g', 'b']

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], color=color, alpha=.8,
                label=target_name)

plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA of IRIS dataset')

plt.show()
